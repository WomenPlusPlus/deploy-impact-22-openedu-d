# %% [markdown]
# # How to use this notebook?
#
# You need to install the requirements:
#
# ```
# pip install -r requirements.txt
# ```
#
# Then you can execute the cells in the notebook...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
MERLOT_LIST_PAGE_URL = "https://merlot.org/merlot/materials.htm"

# %%
MERLOT_VIVEW_PAGE_URL = "https://merlot.org/merlot/viewMaterial.htm"

# %%
SCRAPED_PAGE_NUMBERS = range(1,51)

# %%
EXTRACTED_IDS = []

# %%
EXTRACTED_MATERIAL_ENTITIES = []

# %%
for page_num in SCRAPED_PAGE_NUMBERS:
    res = requests.get(f"{MERLOT_LIST_PAGE_URL}?page={page_num}")
    soup = BeautifulSoup(res.text, "html.parser")
    materials = soup.find_all('div', class_ = 'card merlot-material-item')
    for material in materials:
        title_a = material.find('a')
        id = title_a['href'].split('id=')[1]
        EXTRACTED_IDS.append(id)

# %%
for id in EXTRACTED_IDS:
    res = requests.get(f"{MERLOT_VIVEW_PAGE_URL}?id={id}")
    soup = BeautifulSoup(res.text, "html.parser")
    material_name = soup.find('h2').text.strip()
    material_desc = soup.find('div',id='material_description').text.strip()
    material_raw_disciplines = []

    for li in soup.find('ul',class_='list-unstyled list-small-mb').find_all('li'):
        material_raw_disciplines.append(li.text.strip())

    material_disciplines = [" ".join(dsc.split()).replace('/','+') for dsc in material_raw_disciplines] # each + is a different discipline

    material_meta_data = {}
    for row in soup.find_all('div',class_='col detail-more-about'):
        dts = row.find_all('dt')
        dds = row.find_all('dd')
        for x, y in zip(dts, dds):
            material_meta_data[x.text.strip()] = y.text.strip()
    
    MATERIAL_ENTITY = {
        'name': material_name,
        'description': material_desc,
        'disciplines': material_disciplines
    }
    
    for metadata in material_meta_data:
        MATERIAL_ENTITY[metadata] = material_meta_data[metadata]
    
    EXTRACTED_MATERIAL_ENTITIES.append(MATERIAL_ENTITY)

# %%
extracted_df = pd.DataFrame(EXTRACTED_MATERIAL_ENTITIES)

# %%
extracted_df.to_csv('merlot.csv')

# %%
extracted_df
# Out:
#                                           name  \
# 0                 Authentic Assessment Toolbox
# 1                       DNA from the Beginning
# 2                     Assessing Blood Pressure
# 3     LangMedia Foreign Language Media Archive
# 4           Mathematical Visualization Toolkit
# ...                                        ...
# 1195                        Endangered Species
# 1196                         Escher Web Sketch
# 1197                               Essay Punch
# 1198          Essentials of Marketing Research
# 1199                             Evolution Lab
#
#                                             description  \
# 0     The Authentic Assessment Toolbox site is a tut...
# 1     DNA from the Beginning is an animated tutorial...
# 2     ADOBE FLASH REQUIRED.  This learning module pr...
# 3     This site presents information on culture and ...
# 4     This site consists of a collection of plotting...
# ...                                                 ...
# 1195  A comprehensive gateway site to information on...
# 1196  Drawing program which transforms into symmetri...
# 1197  Commercial product that proposes a topic and l...
# 1198  This is a free, online textbook offered by Boo...
# 1199  A Step by step tutorial of Darwinian principle...
#
#                                             disciplines  \
# 0     [Academic Support Services + Faculty Developme...
# 1     [Science and Technology + Agriculture and Envi...
# 2     [Workforce Development + Technical Allied Heal...
# 3     [Humanities + World Languages + Multilingual R...
# 4     [Mathematics and Statistics + Mathematics + Ca...
# ...                                                 ...
# 1195  [Science and Technology + Biology + Ecology an...
# 1196  [Mathematics and Statistics + Mathematics + Ge...
# 1197  [Humanities + World Languages + ESL or EFL + L...
# 1198           [Business + Marketing + Market Research]
# 1199  [Science and Technology + Biology + Evolutiona...
#
#               Material Type: Date Added to MERLOT: Date Modified in MERLOT:  \
# 0                   Tutorial       January 6, 2003         October 11, 2022
# 1                 Simulation        April 11, 2000       September 21, 2022
# 2                   Tutorial        April 21, 2004             July 9, 2022
# 3                 Simulation      January 10, 2002              May 6, 2022
# 4                 Simulation         July 17, 2001         October 13, 2022
# ...                      ...                   ...                      ...
# 1195      Reference Material     December 27, 2002       September 14, 2022
# 1196              Simulation         June 12, 1997            June 16, 2021
# 1197                Tutorial        March 13, 2001             May 21, 2020
# 1198  Open (Access) Textbook      January 12, 2011            July 29, 2020
# 1199              Simulation         June 26, 2005        December 14, 2021
#
#                                                 Author:          Submitter:  \
# 0              Jon Mueller, \nNorth Central College, IL        Cris Guenter
# 1                         Cold Spring Harbor Laboratory           Jeff Bell
# 2     Andrew Winterstein, \nUniversity of Wisconsin ...  Andrew Winterstein
# 3       Lang Media, \n                    Five Colleges     Elizabeth Pyatt
# 4     University of Colorado at Boulder, Department ...       Kurt Cogswell
# ...                                                 ...                 ...
# 1195  North American Association for Environmental E...          Marty Zahn
# 1196                                                NaN         Ric Stewart
# 1197                                     Merit Software    Jeanne Gilleland
# 1198  Paurav Shukla, \n                    Bookboon.com         Cathy Swift
# 1199                                      Dr. Leif Saul        Nic DeFendis
#
#                                       Primary Audience:  \
# 0     College General Ed,\n                \n       ...
# 1                                    College General Ed
# 2                                    College General Ed
# 3                                    College General Ed
# 4                                    College General Ed
# ...                                                 ...
# 1195  Grade School,\n                \n             ...
# 1196                                 College General Ed
# 1197                                 College General Ed
# 1198  College Upper Division,\n                \n   ...
# 1199                                        High School
#
#                                       Technical Format:  \
# 0                                               Website
# 1                                               Website
# 2                                               Website
# 3                                               Website
# 4     Website,\n                                  \n...
# ...                                                 ...
# 1195                                                NaN
# 1196                                                NaN
# 1197                                            Website
# 1198                                                PDF
# 1199  Website,\n                                  \n...
#
#            Mobile Compatibility:  \
# 0     Not specified at this time
# 1     Not specified at this time
# 2     Not specified at this time
# 3     Not specified at this time
# 4     Not specified at this time
# ...                          ...
# 1195  Not specified at this time
# 1196  Not specified at this time
# 1197  Not specified at this time
# 1198  Not specified at this time
# 1199  Not specified at this time
#
#                                 Technical Requirements: Language:  \
# 0         Internet Explorer is recommend by the author.   English
# 1                                 Flash 3 and RealAudio   English
# 2                                                   NaN   English
# 3                                 Real Player required.   English
# 4     Java-enabled Browser, preferably Internet Expl...   English
# ...                                                 ...       ...
# 1195                                                NaN   English
# 1196                                                NaN   English
# 1197                                                NaN   English
# 1198                                                NaN   English
# 1199                                                NaN   English
#
#      Cost Involved: Source Code Available:  \
# 0                No                     No
# 1                No                     No
# 2                No                     No
# 3                No                     No
# 4                No                     No
# ...             ...                    ...
# 1195             No                     No
# 1196             No                     No
# 1197             No                    Yes
# 1198             No                Unknown
# 1199             No                     No
#
#      Accessibility Information Available:  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                      No
# ...                                   ...
# 1195                                   No
# 1196                              Unknown
# 1197                                   No
# 1198                              Unknown
# 1199                                   No
#
#                                       Creative Commons:  \
# 0     This work is licensed under a\n               ...
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 1195                                                 No
# 1196                                                 No
# 1197                                                 No
# 1198                                            Unknown
# 1199                                                 No
#
#                                                Authors: Languages:
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 1195                                                NaN        NaN
# 1196  Wes Hardaker\n                    \n          ...        NaN
# 1197                                                NaN        NaN
# 1198                                                NaN        NaN
# 1199                                                NaN        NaN
#
# [1200 rows x 19 columns]
